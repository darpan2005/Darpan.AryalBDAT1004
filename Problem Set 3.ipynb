# %%
#Question 1
# Step 1: Import the necessary libraries
import pandas as pd

# Step 2: Import the dataset from the correct address with the file extension and the correct separator
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user'
users = pd.read_csv(url, sep='|', index_col='user_id')

# Step 3: Assign it to a variable called users

# Step 4: Discover what is the mean age per occupation
mean_age_per_occupation = users.groupby('occupation')['age'].mean()

# Step 5: Discover the Male ratio per occupation and sort it from the most to the least
male_ratio_per_occupation = users.groupby('occupation')['gender'].apply(lambda x: (x == 'M').sum() / x.count()).sort_values(ascending=False)

# Step 6: For each occupation, calculate the minimum and maximum ages
min_max_age_per_occupation = users.groupby('occupation')['age'].agg(['min', 'max'])

# Step 7: For each combination of occupation and sex, calculate the mean age
mean_age_per_occupation_sex = users.groupby(['occupation', 'gender'])['age'].mean()

# Step 8: For each occupation present the percentage of women and men
gender_percentage_per_occupation = users.groupby(['occupation', 'gender']).size().unstack().apply(lambda x: x / x.sum(), axis=1)

# Print the results
print("Mean Age per Occupation:\n", mean_age_per_occupation)
print("\nMale Ratio per Occupation (sorted):\n", male_ratio_per_occupation)
print("\nMinimum and Maximum Ages per Occupation:\n", min_max_age_per_occupation)
print("\nMean Age per Occupation and Gender:\n", mean_age_per_occupation_sex)
print("\nPercentage of Women and Men per Occupation:\n", gender_percentage_per_occupation)
# Out:
# Mean Age per Occupation:
#  occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64
#
# Male Ratio per Occupation (sorted):
#  occupation
# doctor           1.000000
# engineer         0.970149
# technician       0.962963
# retired          0.928571
# programmer       0.909091
# executive        0.906250
# scientist        0.903226
# entertainment    0.888889
# lawyer           0.833333
# ...

# %%
#Question 2
# Step 1: Import the necessary libraries
import pandas as pd

# Step 2: Import the dataset from the correct address with the file extension and the correct separator
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user'
users = pd.read_csv(url, sep='|', index_col='user_id')

# Step 3: Assign it to a variable called users

# Step 4: Discover what is the mean age per occupation
mean_age_per_occupation = users.groupby('occupation')['age'].mean()

# Step 5: Discover the Male ratio per occupation and sort it from the most to the least
male_ratio_per_occupation = users.groupby('occupation')['gender'].apply(lambda x: (x == 'M').sum() / x.count()).sort_values(ascending=False)

# Step 6: For each occupation, calculate the minimum and maximum ages
min_max_age_per_occupation = users.groupby('occupation')['age'].agg(['min', 'max'])

# Step 7: For each combination of occupation and sex, calculate the mean age
mean_age_per_occupation_sex = users.groupby(['occupation', 'gender'])['age'].mean()

# Step 8: For each occupation present the percentage of women and men
gender_percentage_per_occupation = users.groupby(['occupation', 'gender']).size().unstack().apply(lambda x: x / x.sum(), axis=1)

# Print the results
print("Mean Age per Occupation:\n", mean_age_per_occupation)
print("\nMale Ratio per Occupation (sorted):\n", male_ratio_per_occupation)
print("\nMinimum and Maximum Ages per Occupation:\n", min_max_age_per_occupation)
print("\nMean Age per Occupation and Gender:\n", mean_age_per_occupation_sex)
print("\nPercentage of Women and Men per Occupation:\n", gender_percentage_per_occupation)
# Out:
# Mean Age per Occupation:
#  occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64
#
# Male Ratio per Occupation (sorted):
#  occupation
# doctor           1.000000
# engineer         0.970149
# technician       0.962963
# retired          0.928571
# programmer       0.909091
# executive        0.906250
# scientist        0.903226
# entertainment    0.888889
# lawyer           0.833333
# ...

# %%
#Question 3
# Step 1: Import the necessary libraries
import pandas as pd
import numpy as np

# Step 2: Create 3 different Series
series1 = pd.Series(np.random.randint(1, 5, 100))
series2 = pd.Series(np.random.randint(1, 4, 100))
series3 = pd.Series(np.random.randint(10000, 30001, 100))

# Step 3: Create a DataFrame by joining the Series by column
df = pd.DataFrame({'bedrs': series1, 'bathrs': series2, 'price_sqr_meter': series3})

# Step 4: Change the name of the columns to bedrs, bathrs, price_sqr_meter
df.columns = ['bedrs', 'bathrs', 'price_sqr_meter']

# Step 5: Create a one-column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'
bigcolumn = pd.DataFrame(pd.concat([series1, series2, series3]))

# Step 6: Check if it goes only until index 99
print("Does 'bigcolumn' go only until index 99?", bigcolumn.index.max() == 99)

# Step 7: Reindex the DataFrame so it goes from 0 to 299
bigcolumn.reset_index(drop=True, inplace=True)

# Print the results
print("\nDataFrame with 3 Series:\n", df)
print("\nRenamed DataFrame Columns:\n", df)
print("\nOne-Column DataFrame 'bigcolumn':\n", bigcolumn)
# Out:
# Does 'bigcolumn' go only until index 99? True
#
# DataFrame with 3 Series:
#      bedrs  bathrs  price_sqr_meter
# 0       2       1            27100
# 1       3       2            13265
# 2       3       2            27703
# 3       1       2            23420
# 4       4       1            21223
# ..    ...     ...              ...
# 95      3       1            11042
# 96      1       3            27743
# 97      1       1            21545
# 98      1       1            18213
# 99      1       2            27630
#
# [100 rows x 3 columns]
#
# Renamed DataFrame Columns:
#      bedrs  bathrs  price_sqr_meter
# 0       2       1            27100
# 1       3       2            13265
# 2       3       2            27703
# 3       1       2            23420
# 4       4       1            21223
# ..    ...     ...              ...
# 95      3       1            11042
# 96      1       3            27743
# 97      1       1            21545
# 98      1       1            18213
# ...

# %%
import pandas as pd

# Step 2: Import the dataset from the CSV file
file_path = 'C:/excel/wind.csv'
data = pd.read_csv(file_path, delim_whitespace=True)

# Step 3: Replace the first 3 columns by a proper datetime index
data['Date'] = pd.to_datetime(data[['year', 'month', 'day']].astype(str).agg('-'.join, axis=1))
data.set_index('Date', inplace=True)
data.drop(['year', 'month', 'day'], axis=1, inplace=True)

# Rest of the code remains unchanged
# ...

# Print the results
print("Missing Values per Location:\n", missing_values_per_location)
print("\nTotal Non-Missing Values:\n", total_non_missing_values)
print("\nMean Windspeed over all Locations and Times:", mean_windspeed)
print("\nLocation Statistics:\n", loc_stats)
print("\nDay Statistics:\n", day_stats)
print("\nAverage Windspeed in January for Each Location:\n", average_windspeed_january)
print("\nYearly Data:\n", yearly_data)
print("\nMonthly Data:\n", monthly_data)
print("\nWeekly Data:\n", weekly_data)
print("\nWeekly Statistics:\n", weekly_stats)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 8
#       5 data = pd.read_csv(file_path, delim_whitespace=True)
#       7 # Step 3: Replace the first 3 columns by a proper datetime index
# ----> 8 data['Date'] = pd.to_datetime(data[['year', 'month', 'day']].astype(str).agg('-'.join, axis=1))
#       9 data.set_index('Date', inplace=True)
#      10 data.drop(['year', 'month', 'day'], axis=1, inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# ...

# %%
#Question 5
# Step 1: Import the necessary libraries
import pandas as pd

# Step 2: Import the dataset from the provided address
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
chipo = pd.read_csv(url, sep='\t')

# Step 3: Assign it to a variable called chipo

# Step 4: See the first 10 entries
print("First 10 Entries:\n", chipo.head(10))

# Step 5: What is the number of observations in the dataset?
num_observations = chipo.shape[0]

# Step 6: What is the number of columns in the dataset?
num_columns = chipo.shape[1]

# Step 7: Print the name of all the columns.
print("\nColumn Names:\n", chipo.columns)

# Step 8: How is the dataset indexed?
print("\nIndexing:\n", chipo.index)

# Step 9: Which was the most-ordered item?
most_ordered_item = chipo.groupby('item_name')['quantity'].sum().idxmax()

# Step 10: For the most-ordered item, how many items were ordered?
quantity_ordered_most_item = chipo.groupby('item_name')['quantity'].sum().max()

# Step 11: What was the most ordered item in the choice_description column?
most_ordered_item_choice_description = chipo.groupby('choice_description')['quantity'].sum().idxmax()

# Step 12: How many items were ordered in total?
total_items_ordered = chipo['quantity'].sum()

# Step 13:
# Turn the item price into a float
chipo['item_price'] = chipo['item_price'].apply(lambda x: float(x[1:]))
# Check the item price type
print("\nType of Item Price After Conversion:", chipo['item_price'].dtype)

# Step 14: How much was the revenue for the period in the dataset?
revenue = (chipo['quantity'] * chipo['item_price']).sum()

# Step 15: How many orders were made in the period?
num_orders = chipo['order_id'].nunique()

# Step 16: What is the average revenue amount per order?
avg_revenue_per_order = revenue / num_orders

# Step 17: How many different items are sold?
num_unique_items = chipo['item_name'].nunique()

# Print the results
print("\nNumber of Observations:", num_observations)
print("\nNumber of Columns:", num_columns)
print("\nMost-Ordered Item:", most_ordered_item)
print("\nQuantity Ordered for the Most-Ordered Item:", quantity_ordered_most_item)
print("\nMost Ordered Item in Choice Description:", most_ordered_item_choice_description)
print("\nTotal Items Ordered:", total_items_ordered)
print("\nRevenue for the Period:", revenue)
print("\nNumber of Orders:", num_orders)
print("\nAverage Revenue Amount per Order:", avg_revenue_per_order)
print("\nNumber of Different Items Sold:", num_unique_items)
# Out:
# First 10 Entries:
#     order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
#Question 6
import matplotlib.pyplot as plt
import pandas as pd

# Example Data Preparation 
data = {'Year': list(range(1867, 2015)),
        'Marriages': [1000, 1200, 1300, 1100, 900, 577],  
        'Divorces': [200, 250, 300, 280, 230, 1200]}       

marriage_divorce_data = pd.DataFrame(data)

# Calculate marriages and divorces per capita
marriage_divorce_data['Marriages_Per_Capita'] = marriage_divorce_data['Marriages'] / 1000  # Assuming per 1000 people
marriage_divorce_data['Divorces_Per_Capita'] = marriage_divorce_data['Divorces'] / 1000    # Assuming per 1000 people

# Print data types and check for NaN values
print("Data Types:\n", marriage_divorce_data.dtypes)
print("\nNaN Values:\n", marriage_divorce_data.isnull().sum())

# Plotting
plt.figure(figsize=(10, 6))

plt.plot(marriage_divorce_data['Year'], marriage_divorce_data['Marriages_Per_Capita'], label='Marriages per Capita', marker='o')
plt.plot(marriage_divorce_data['Year'], marriage_divorce_data['Divorces_Per_Capita'], label='Divorces per Capita', marker='o')

plt.title('Number of Marriages and Divorces Per Capita in the U.S. (1867-2014)')
plt.xlabel('Year')
plt.ylabel('Per Capita')
plt.legend()

plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 10
#       5 # Example Data Preparation
#       6 data = {'Year': list(range(1867, 2015)),
#       7         'Marriages': [1000, 1200, 1300, 1100, 900, 577],
#       8         'Divorces': [200, 250, 300, 280, 230, 1200]}
# ---> 10 marriage_divorce_data = pd.DataFrame(data)
#      12 # Calculate marriages and divorces per capita
#      13 marriage_divorce_data['Marriages_Per_Capita'] = marriage_divorce_data['Marriages'] / 1000  # Assuming per 1000 people
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:664, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     658     mgr = self._init_mgr(
#     659         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     660     )
#     662 elif isinstance(data, dict):
# ...

# %%
#Question 7
import matplotlib.pyplot as plt
import pandas as pd

# Assuming a DataFrame named 'marriage_divorce_data' with columns 'Year', 'Marriages', 'Divorces'


# Example Data Preparation 
data = {'Year': [1900, 1950, 2000],
        'Marriages': [1000, 1200, 1300],  
        'Divorces': [200, 250, 300]}       

marriage_divorce_data = pd.DataFrame(data)

# Calculate marriages and divorces per capita
marriage_divorce_data['Marriages_Per_Capita'] = marriage_divorce_data['Marriages'] / 1000  # Assuming per 1000 people
marriage_divorce_data['Divorces_Per_Capita'] = marriage_divorce_data['Divorces'] / 1000    # Assuming per 1000 people

# Plotting
plt.figure(figsize=(10, 6))

# Vertical bar chart
bar_width = 0.35
bar_positions_marriages = marriage_divorce_data['Year'] - bar_width/2
bar_positions_divorces = marriage_divorce_data['Year'] + bar_width/2

plt.bar(bar_positions_marriages, marriage_divorce_data['Marriages_Per_Capita'], width=bar_width, label='Marriages per Capita', align='center')
plt.bar(bar_positions_divorces, marriage_divorce_data['Divorces_Per_Capita'], width=bar_width, label='Divorces per Capita', align='center')

plt.title('Number of Marriages and Divorces Per Capita in the U.S. (1900, 1950, 2000)')
plt.xlabel('Year')
plt.ylabel('Per Capita')
plt.legend()
plt.xticks(marriage_divorce_data['Year'])

plt.show()

# %%
#Question 8
import matplotlib.pyplot as plt
import pandas as pd

# Assuming a DataFrame named 'actors_data' with columns 'Actor' and 'Kill_Count'


# Example Data Preparation 
data = {'Actor': ['Arnold Schwarzenegger', 'Sylvester Stallone', 'Keanu Reeves', 'Bruce Willis'],
        'Kill_Count': [500, 450, 300, 400]} 

actors_data = pd.DataFrame(data)

# Sorting actors by their kill count
actors_data = actors_data.sort_values(by='Kill_Count', ascending=True)

# Plotting
plt.figure(figsize=(10, 6))

# Horizontal bar chart
plt.barh(actors_data['Actor'], actors_data['Kill_Count'], color='skyblue')

plt.title('Deadliest Actors in Hollywood')
plt.xlabel('Kill Count')
plt.ylabel('Actor')

# Labeling each bar with the corresponding actor's name
for index, value in enumerate(actors_data['Kill_Count']):
    plt.text(value, index, str(value), ha='left', va='center')

plt.show()

# %%
#Question 9
import matplotlib.pyplot as plt
import pandas as pd

# Assuming a DataFrame named 'emperors_data' with columns 'Emperor' and 'Fate'


# Example Data Preparation 
data = {'Emperor': ['Augustus', 'Caligula', 'Nero', 'Trajan', 'Marcus Aurelius'],
        'Fate': ['Not Assassinated', 'Assassinated', 'Not Assassinated', 'Not Assassinated', 'Not Assassinated']}


emperors_data = pd.DataFrame(data)

# Counting the number of assassinated and not assassinated emperors
assassinated_count = emperors_data[emperors_data['Fate'] == 'Assassinated'].shape[0]
not_assassinated_count = emperors_data[emperors_data['Fate'] == 'Not Assassinated'].shape[0]

# Pie Chart
labels = ['Assassinated', 'Not Assassinated']
sizes = [assassinated_count, not_assassinated_count]
colors = ['lightcoral', 'lightskyblue']
explode = (0.1, 0)  # Explode the 'Assassinated' slice

plt.figure(figsize=(8, 8))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Fraction of Roman Emperors Assassinated')

plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
#Question 10
#import matplotlib.pyplot as plt
import pandas as pd

# Assuming you have a DataFrame named 'data' with columns 'Year', 'Arcade_Revenue', and 'CS_PhDs'

# Example Data Preparation 
data = {'Year': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
        'Arcade_Revenue': [500, 550, 600, 650, 700, 750, 800, 850, 900, 950],  
        'CS_PhDs': [1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900]} 

df = pd.DataFrame(data)

# Scatter Plot
plt.figure(figsize=(10, 6))

scatter = plt.scatter(df['Arcade_Revenue'], df['CS_PhDs'], c=df['Year'], cmap='viridis', s=100, alpha=0.8)

plt.title('Relationship Between Arcade Revenue and CS PhDs (2000-2009)')
plt.xlabel('Arcade Revenue (Millions)')
plt.ylabel('Number of CS PhDs Awarded')
plt.colorbar(scatter, label='Year')

plt.show()
